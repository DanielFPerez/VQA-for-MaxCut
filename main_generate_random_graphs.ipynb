# %% [markdown]
# ### Script to generate Erdos-Renyi random graphs

# %%
from src.utils import *

# %%
num_graphs = 100
num_nodes = 20  # Adjust as needed
edge_prob = 0.5  # Adjust as needed

# %%
random_graphs = generate_random_graphs(num_graphs, num_nodes, edge_prob)

# %%
show_graph(random_graphs[0])

# %% [markdown]
# ### Save graphs

# %%
dst_dir = f"./data/graphs-{num_nodes}nodes_{num_graphs}elems.pkl"

# %%
save_pickle(random_graphs, dst_dir)
# Out:
# Data saved to ./data/graphs-20nodes_100elems.pkl.
# 0
